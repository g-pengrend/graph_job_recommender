# %%
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
import pickle
import ast
import torch
import torch.nn.functional as F
import numpy as np
from transformers import AutoTokenizer, AutoModel

# %%
# Mean Pooling - Takes attention mask into account for correct averaging
def job_title_mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0]  # First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# Function to get embeddings for a batch of job titles
def get_job_title_embeddings(job_titles, tokenizer, model, batch_size=32, device='cpu'):
    embeddings = []
    
    for i in range(0, len(job_titles), batch_size):
        batch_titles = job_titles[i:i + batch_size]
        
        # Tokenize the job titles
        encoded_input = tokenizer(batch_titles, padding=True, truncation=True, return_tensors='pt').to(device)
        
        # Compute token embeddings
        with torch.no_grad():
            model_output = model(**encoded_input)
        
        # Perform mean pooling
        sentence_embeddings = job_title_mean_pooling(model_output, encoded_input['attention_mask'])
        
        # Normalize the embeddings
        sentence_embeddings = F.normalize(sentence_embeddings, p=2, dim=1)
        
        # Append to list
        embeddings.append(sentence_embeddings.cpu().numpy())
    
    # Return embeddings as a numpy array
    return np.vstack(embeddings)

# %%
mlb = MultiLabelBinarizer()
mlb.fit([['contract'], ['fulltime'], ['internship'], ['parttime'], ['temporary']])

print("Loading graph from pickle file...")
with open('./recommendation_cache/final_complete_graph.pkl', 'rb') as f:
    graph = pickle.load(f)
print("Setup complete!")
# Out:
# Loading graph from pickle file...
# Setup complete!

# %%
# Convert graph nodes to DataFrame
nodes_data = []
for node, attrs in graph.nodes(data=True):
    node_dict = {'node_id': node}
    node_dict.update(attrs)
    nodes_data.append(node_dict)

df = pd.DataFrame(nodes_data)

df.head()
# Out:
#   node_id                                job_title_embedding  \
# 0   job_0  [-0.0323692635, 0.037560612, -0.0851607397, -0...
# 1   job_1  [-0.0593948737, 0.0716273487, -0.0681853294, 0...
# 2   job_2  [-0.0508020073, -0.00822946988, -0.0356351659,...
# 3   job_3  [-0.0720216036, -0.000101672507, 0.0526241288,...
# 4   job_4  [-0.0362352729, 0.0467952862, -0.0649954677, -...
#
#                            job_description_embedding  \
# 0  [0.0364928544, 0.0229546651, 0.0382401571, 0.0...
# 1  [-0.00784693379, 0.0408150293, -0.0307610631, ...
# 2  [-0.00660971645, 0.0656373128, -0.0250155218, ...
# 3  [0.00460857758, 0.0135099608, 0.048739396, -0....
# 4  [0.0213460047, 0.0483995192, -0.00763951195, 0...
#
#                           company job_type_encoding  is_remote  \
# 0          PHOENIX OPCO PTE. LTD.   [0, 1, 0, 0, 0]      False
# 1     Kopitiam Investment Pte Ltd   [0, 1, 0, 0, 0]      False
# 2                 Oomph Pte. Ltd.   [0, 1, 0, 0, 0]      False
# 3  ECOCLEAN MAINTENANCE PTE. LTD.   [0, 1, 0, 0, 0]      False
# 4                 Anradus Pte Ltd   [0, 1, 0, 0, 0]      False
#
#                                    lat_long
# 0  (1.2744927000000001, 103.84404662674353)
# 1                  (1.2899175, 103.8519072)
# 2                  (1.2899175, 103.8519072)
# 3                  (1.2899175, 103.8519072)
# 4          (1.28308855, 103.85046008586423)

# %%
df['job_title_embedding'] = df['job_title_embedding'].apply(np.array)

# %%
df_old = pd.read_csv('6.1.cleaned_and_merged_back.csv')
df_old['lat_long'] = df_old['lat_long'].apply(ast.literal_eval)
# Out:
# C:\Users\Brandon\AppData\Local\Temp\ipykernel_13216\3689362099.py:1: DtypeWarning: Columns (28,29,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_old = pd.read_csv('6.1.cleaned_and_merged_back.csv')

# %%
# Load tokenizer and model from Hugging Face Hub
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L12-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L12-v2')

# If GPU is available, move model to GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)

# %%
# Process job titles in batches
job_titles = df_old['title'].tolist()
embeddings = get_job_title_embeddings(job_titles, tokenizer, model, batch_size=256, device=device)

# Assign the embeddings to the dataframe as a list for each row
df_old['job_title_embedding'] = [embedding for embedding in embeddings]

# %%
df_old['job_title_embedding'][0]
# Out:
# array([-3.23692635e-02,  3.75606120e-02, -8.51607397e-02, -4.53846455e-02,
#        -5.46593554e-02, -2.79194303e-02,  2.78429296e-02,  2.15941686e-02,
#         3.25031728e-02,  8.87234812e-04,  3.66467610e-02, -4.50273678e-02,
#        -1.09668206e-02, -3.68140303e-02, -4.51355092e-02,  5.84830716e-02,
#         1.14421636e-01,  3.79366949e-02, -1.09098526e-02, -4.50774394e-02,
#        -6.36187941e-02, -2.83169001e-02, -7.49196559e-02,  4.60793413e-02,
#        -8.73038266e-03,  4.90450747e-02, -2.30729543e-02,  8.33488330e-02,
#         1.08598638e-02, -8.04005265e-02, -9.02405754e-02,  2.68752687e-02,
#         2.91939843e-02,  2.03662012e-02, -4.73717880e-03, -2.22695544e-02,
#        -2.55234633e-02,  4.52349409e-02,  2.86074150e-02, -1.15934608e-03,
#        -2.06206571e-02, -9.99114104e-03, -1.18169105e-02, -2.74297539e-02,
#        -8.19667950e-02,  1.21426117e-02, -5.15504405e-02, -1.48908487e-02,
#         3.12867016e-02,  4.25315909e-02,  5.44571318e-02,  7.82229751e-03,
#         1.11881550e-02,  5.47044016e-02, -2.20145993e-02,  6.60661459e-02,
#        -4.19043761e-04,  1.51083982e-02, -3.81165333e-02, -1.69295501e-02,
#        -2.83929724e-02,  2.91143940e-03, -5.51629476e-02, -2.26649194e-04,
#        -3.43298875e-02, -4.12429823e-03, -2.98547298e-02, -3.37917432e-02,
#        -6.67487271e-03, -5.16205207e-02, -2.35408433e-02, -6.55120388e-02,
#        -5.43309487e-02, -3.18038044e-03,  1.18260279e-01,  1.23469625e-02,
#         3.10083572e-02, -6.57702377e-03, -4.33183387e-02, -3.15327570e-02,
#        -5.32171801e-02, -7.90918916e-02, -8.97181183e-02, -5.54492138e-02,
#        -4.25002277e-02, -7.56329333e-04, -1.65863000e-02, -1.06061913e-01,
#         2.59988382e-02,  2.07840949e-02,  1.33714674e-03, -9.26006585e-03,
#         3.14535759e-03, -6.02836423e-02, -1.83181390e-02,  2.56741643e-02,
#         9.14465636e-03, -5.55429906e-02, -8.84505436e-02,  3.91282260e-01,
#        -2.47407961e-03, -2.23034644e-03, -6.44639209e-02,  8.10331851e-03,
#         1.30994283e-02, -3.24723758e-02, -2.85277367e-02,  1.55969588e-02,
#         4.52222973e-02,  1.54045047e-02,  3.46561940e-03, -1.48824835e-02,
#         1.11183515e-02, -9.05900355e-03,  3.09257172e-02, -6.48853332e-02,
#         1.03582293e-01,  3.51125263e-02,  9.33734607e-03, -1.14919676e-03,
#        -3.30896378e-02, -4.69578356e-02, -6.55823341e-03, -2.30119191e-03,
#         5.29548526e-02, -2.53250729e-02, -1.31702144e-02,  2.20445693e-02,
#        -4.19955254e-02, -4.64358702e-02,  3.01925503e-02, -4.76837568e-02,
#        -4.50549182e-03, -2.38191169e-02,  1.00967191e-01, -1.76783213e-32,
#        -5.18036308e-03,  3.28982249e-02, -5.42606685e-05,  1.69234872e-02,
#         6.99944422e-02,  5.34766354e-02,  3.79161797e-02, -1.46630788e-02,
#        -3.34069971e-03,  3.03177554e-02,  8.30600858e-02,  1.31890038e-02,
#        -4.75431141e-03, -6.19639782e-03, -2.46302467e-02, -2.20883377e-02,
#        -2.93468554e-02,  4.17624228e-02,  1.27821313e-02,  2.43057236e-02,
#        -1.16377054e-02,  6.14821166e-02,  8.54958892e-02, -4.65557948e-02,
#         3.98231950e-03, -2.19085813e-02, -1.10072725e-01, -1.88876735e-03,
#         2.45277695e-02, -3.92255001e-02, -1.77790280e-02,  4.10831310e-02,
#         2.90686078e-02, -8.24375972e-02, -1.21110445e-03, -7.98466243e-03,
#         5.42106181e-02, -2.56740227e-02, -2.70067137e-02,  2.29956564e-02,
#        -3.11662741e-02,  6.19803108e-02, -9.23316181e-03, -2.64205784e-02,
#        -2.06903275e-03,  3.84881385e-02,  1.02722503e-01, -1.87071436e-03,
#        -2.34825388e-02, -4.34261151e-02, -1.19220717e-02,  1.57711282e-02,
#         5.30413501e-02,  1.01837898e-02, -1.61338169e-02,  5.96855059e-02,
#        -7.21319690e-02, -7.72478729e-02, -4.46728319e-02, -1.75949782e-02,
#         3.65964286e-02, -1.43841049e-02, -7.24985972e-02,  1.35575728e-02])

# %%
type(df['job_title_embedding'][0]), type(df_old['job_title_embedding'][0])
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
# Convert lists to numpy arrays in df to match the format of df_old
df['job_title_embedding'] = df['job_title_embedding'].apply(np.array)

# Tolerance-based comparison using np.allclose to account for small differences
mismatches = ~np.array([np.allclose(a, b, atol=1e-6) for a, b in zip(df['job_title_embedding'], df_old['job_title_embedding'])])

# Get indices of mismatches
mismatch_indices = np.where(mismatches)[0]

# Print indices of mismatches
if len(mismatch_indices) > 0:
    print("Mismatches found at indices:", mismatch_indices)
else:
    print("All embeddings match exactly.")
# Out:
# All embeddings match exactly.

# %%
# Check if lat_long values match between df and df_old
mismatches = df['lat_long'] != df_old['lat_long']

# Get indices of mismatches
mismatch_indices = mismatches[mismatches].index

# Print indices of mismatches
if not mismatch_indices.empty:
    print("Mismatches found at indices:", mismatch_indices.tolist())
else:
    print("All lat_long values match exactly.")
# Out:
# All lat_long values match exactly.

# %%
df.shape, df_old.shape
# Out:
# ((25142, 7), (25142, 34))

# %%
# Identify columns that are in both df and df_old
common_columns = df.columns.intersection(df_old.columns)

# Select only the columns in df_old that are not in df
df_old_unique = df_old[df_old.columns.difference(common_columns)]

# Merge on the index, bringing only unique columns from df_old
merged_df = df.merge(df_old_unique, left_index=True, right_index=True, how='left')

# Display the merged DataFrame
print("Merged DataFrame without duplicated columns:")
print(merged_df)
# Out:
# Merged DataFrame without duplicated columns:
#          node_id                                job_title_embedding  \
# 0          job_0  [-0.0323692635, 0.037560612, -0.0851607397, -0...
# 1          job_1  [-0.0593948737, 0.0716273487, -0.0681853294, 0...
# 2          job_2  [-0.0508020073, -0.00822946988, -0.0356351659,...
# 3          job_3  [-0.0720216036, -0.000101672507, 0.0526241288,...
# 4          job_4  [-0.0362352729, 0.0467952862, -0.0649954677, -...
# ...          ...                                                ...
# 25137  job_25137  [-0.0373321287, 0.0151110766, -0.0551175214, 0...
# 25138  job_25138  [-0.0560089499, 0.0340756066, -0.0320017785, -...
# 25139  job_25139  [0.0100341607, -0.0136072841, -0.0523362756, 0...
# 25140  job_25140  [-0.023009764, 0.0560570732, -0.0101536363, 0....
# 25141  job_25141  [-0.0467093848, 0.0244118106, 0.000753627974, ...
#
#                                job_description_embedding  \
# 0      [0.0364928544, 0.0229546651, 0.0382401571, 0.0...
# 1      [-0.00784693379, 0.0408150293, -0.0307610631, ...
# 2      [-0.00660971645, 0.0656373128, -0.0250155218, ...
# 3      [0.00460857758, 0.0135099608, 0.048739396, -0....
# 4      [0.0213460047, 0.0483995192, -0.00763951195, 0...
# ...                                                  ...
# 25137  [-0.0348114818, -0.00447259471, 0.00254532835,...
# 25138  [-0.077440314, 0.0442074798, -0.020601498, -0....
# 25139  [0.00701115001, 0.0457365699, 0.0280897208, 0....
# 25140  [0.0260690916, -0.0241503362, 0.00520299748, 0...
# 25141  [-0.043065317, -0.00759273209, -0.054091353, 0...
#
#                                    company job_type_encoding  is_remote  \
# 0                   PHOENIX OPCO PTE. LTD.   [0, 1, 0, 0, 0]      False
# 1              Kopitiam Investment Pte Ltd   [0, 1, 0, 0, 0]      False
# 2                          Oomph Pte. Ltd.   [0, 1, 0, 0, 0]      False
# 3           ECOCLEAN MAINTENANCE PTE. LTD.   [0, 1, 0, 0, 0]      False
# 4                          Anradus Pte Ltd   [0, 1, 0, 0, 0]      False
# ...                                    ...               ...        ...
# 25137                       DXC Technology   [0, 1, 0, 0, 0]      False
# 25138                        ITCAN Pte Ltd   [1, 1, 0, 0, 0]      False
# 25139               RECRUITPEDIA PTE. LTD.   [0, 1, 0, 0, 0]      False
# 25140                       FE CONSULTANCY   [0, 1, 0, 0, 0]      False
# 25141  Sumitomo Mitsui Banking Corporation   [0, 1, 0, 0, 0]      False
#
#                                        lat_long  \
# 0      (1.2744927000000001, 103.84404662674353)
# 1                      (1.2899175, 103.8519072)
# 2                      (1.2899175, 103.8519072)
# 3                      (1.2899175, 103.8519072)
# 4              (1.28308855, 103.85046008586423)
# ...                                         ...
# 25137                  (1.2821897, 103.8062312)
# 25138           (1.2828426, 103.84992848626737)
# 25139                  (1.2781753, 103.8481088)
# 25140                  (1.2899175, 103.8519072)
# 25141                  (1.2839722, 103.8500286)
#
#                                                  address  \
# 0             Tras Street, #9-177 Union Building, 079025
# 1      1 Joo Koon Cir, #13-01 FairPrice Joo Koon, Sin...
# 2      2 Alexandra Rd, #04-01 Delta House, Singapore ...
# 3      1 Yishun Industrial Street 1, #06-27 A'Posh Bi...
# 4                          20 Cecil St, Singapore 049705
# ...                                                  ...
# 25137               1 Depot Cl, #03-01, Singapore 109841
# 25138              30 Cecil St, #18-08, Singapore 049712
# 25139                  146 Robinson Rd, Singapore 068909
# 25140  21 Bukit Batok Cres, #07-84 Wcega Tower, Singa...
# 25141             88 Market St, #33-01, Singapore 048948
#
#                                         banner_photo_url  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      https://d2q79iu7y748jz.cloudfront.net/s/_heade...
# ...                                                  ...
# 25137  https://d2q79iu7y748jz.cloudfront.net/s/_heade...
# 25138                                                NaN
# 25139                                                NaN
# 25140                                                NaN
# 25141  https://d2q79iu7y748jz.cloudfront.net/s/_heade...
#
#                               ceo_name  ...  \
# 0                                  NaN  ...
# 1                                  NaN  ...
# 2                                  NaN  ...
# 3                                  NaN  ...
# 4                                  NaN  ...
# ...                                ...  ...
# 25137  Raul Fernandez, President & CEO  ...
# 25138                              NaN  ...
# 25139                              NaN  ...
# 25140                              NaN  ...
# 25141                 Makoto Takashima  ...
#
#                                                  job_url  \
# 0      https://sg.indeed.com/viewjob?jk=0005a77c5af02f32
# 1      https://sg.indeed.com/viewjob?jk=000989af12dd337f
# 2      https://sg.indeed.com/viewjob?jk=000a01db7a6ccc16
# 3      https://sg.indeed.com/viewjob?jk=000be27bd990645d
# 4      https://sg.indeed.com/viewjob?jk=000c06084a55495e
# ...                                                  ...
# 25137  https://sg.indeed.com/viewjob?jk=fff3514a4d4b29b5
# 25138  https://sg.indeed.com/viewjob?jk=fff7a157262619d5
# 25139  https://sg.indeed.com/viewjob?jk=fff8178deb218454
# 25140  https://sg.indeed.com/viewjob?jk=fffa91c5d0e3d752
# 25141  https://sg.indeed.com/viewjob?jk=fffb23bb5f718b14
#
#                                           job_url_direct            location  \
# 0      https://www.mycareersfuture.gov.sg/job/custome...  Singapore, S00, SG
# 1      https://kopitiam.recruiterpal.com/career/jobs/...                  SG
# 2      https://www.mycareersfuture.gov.sg/job/custome...  Singapore, S00, SG
# 3      https://www.mycareersfuture.gov.sg/job/others/...  Singapore, S00, SG
# 4      http://sg.indeed.com/job/accounts-officer-gl-6...  Pasir Ris, S00, SG
# ...                                                  ...                 ...
# 25137  https://careers.dxc.com/global/en/job/DXTEGLOB...                  SG
# 25138  http://sg.indeed.com/job/batch-operator-dc-ope...                  SG
# 25139  https://www.mycareersfuture.gov.sg/job/admin/b...  Singapore, S00, SG
# 25140  https://www.mycareersfuture.gov.sg/job/general...  Singapore, S00, SG
# 25141  https://www.efinancialcareers.sg/jobs-Singapor...  Singapore, S00, SG
#
#                                           logo_photo_url max_amount  \
# 0                                                    NaN        NaN
# 1      https://d2q79iu7y748jz.cloudfront.net/s/_squar...        NaN
# 2                                                    NaN        NaN
# 3                                                    NaN        NaN
# 4      https://d2q79iu7y748jz.cloudfront.net/s/_squar...        NaN
# ...                                                  ...        ...
# 25137  https://d2q79iu7y748jz.cloudfront.net/s/_squar...        NaN
# 25138  https://d2q79iu7y748jz.cloudfront.net/s/_squar...        NaN
# 25139  https://d2q79iu7y748jz.cloudfront.net/s/_squar...        NaN
# 25140                                                NaN        NaN
# 25141  https://d2q79iu7y748jz.cloudfront.net/s/_squar...        NaN
#
#       min_amount                                     model_response  \
# 0            NaN  Responsibilities\n    Ensure guest experiences...
# 1            NaN  Responsibilities\n Operations\n    Support Out...
# 2            NaN  Aspect 1 Responsibilities\n Actively promote l...
# 3            NaN  Responsibilities\n Respond to emergency calls,...
# 4            NaN  Summary of Job Description for Accounts Office...
# ...          ...                                                ...
# 25137        NaN  Responsibilities\n Monitor calltracking tool q...
# 25138        NaN  Responsibilities\n    DC operation\n    Provid...
# 25139        NaN  Job Highlights\n Startup environment, welcomin...
# 25140        NaN  Responsibilities\n Planning routes and travel ...
# 25141        NaN  Job Responsibilities\n Primary responsibility ...
#
#       salary_source    site                                              title
# 0               NaN  indeed                                             Porter
# 1               NaN  indeed          Outlet Executive - Tan Tock Seng Hospital
# 2               NaN  indeed                                     Sales Promoter
# 3               NaN  indeed           Cleaning Operations Assistant Supervisor
# 4               NaN  indeed                       Accounts Officer (GL) #68959
# ...             ...     ...                                                ...
# 25137           NaN  indeed                     Incident Lifecycle Coordinator
# 25138           NaN  indeed                      Batch Operator, DC Operations
# 25139           NaN  indeed      Business Development Consultant (Recruitment)
# 25140           NaN  indeed                                       TRUCK DRIVER
# 25141           NaN  indeed  Director, AUD Rates Trader, Global Markets and...
#
# [25142 rows x 37 columns]

# %%
merged_df.shape
# Out:
# (25142, 37)

# %%
merged_df.columns
# Out:
# Index(['node_id', 'job_title_embedding', 'job_description_embedding',
#        'company', 'job_type_encoding', 'is_remote', 'lat_long', 'address',
#        'banner_photo_url', 'ceo_name', 'ceo_photo_url', 'cleaned_address',
#        'company_addresses', 'company_description', 'company_industry',
#        'company_num_employees', 'company_revenue', 'company_url',
#        'company_url_direct', 'currency', 'date_posted', 'description_x',
#        'description_y', 'emails', 'id', 'interval', 'job_type', 'job_url',
#        'job_url_direct', 'location', 'logo_photo_url', 'max_amount',
#        'min_amount', 'model_response', 'salary_source', 'site', 'title'],
#       dtype='object')

# %%
# Group by 'id' and list the associated 'node_id' values
id_node_mappings = merged_df.groupby('node_id')['id'].apply(list)

# Display the mapping
print("Node IDs mapped to each ID:")
print(id_node_mappings)

# Define the file path
output_file = '9.2.id_node_mappings.txt'

# Open the file in write mode and save the mappings
with open(output_file, 'w') as f:
    for id_val, node_ids in id_node_mappings.items():
        # Write the id and associated node_ids list to the file
        f.write(f"ID: {id_val} -> Node IDs: {node_ids}\n")

print(f"Mappings saved to {output_file}")
# Out:
# Node IDs mapped to each ID:
# node_id
# job_0       [0005a77c5af02f32]
# job_1       [000989af12dd337f]
# job_10      [001b2c9b4fd18d72]
# job_100     [00fa6252a365193c]
# job_1000    [0a02fc38c0c685a9]
#                    ...
# job_9995    [6596b4e899cf10fa]
# job_9996    [659a44b63abd13a1]
# job_9997    [659d566f44a48a70]
# job_9998    [bf39a3334467678d]
# job_9999    [659d6c7d3bf96c3a]
# Name: id, Length: 25142, dtype: object
# Mappings saved to 9.2.id_node_mappings.txt

# %%
# merged_df.to_csv('9.1.final_with_graph_data.csv', index=False)

# Save merged_df to a pickle file
merged_df.to_pickle("final_complete_graph_dataframe.pkl")
